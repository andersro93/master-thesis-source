# %% [markdown]
# # Reduction results plots

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.float_format', lambda x: '%.10f' % x)

plt.style.use('seaborn-whitegrid')

# %%
# Load the results
cpu_reduction = pd.read_csv("./reduction/reduce_cpu_results.csv", sep=";")
gpu_reduction = pd.read_csv("./reduction/reduce_gpu_results.csv", sep=";")

# %% [markdown]
# # CPU Reduction

# %%
cpu_reduction.describe()
# Out:
#                      1                2                4                8  \
# count 50000.0000000000 50000.0000000000 50000.0000000000 50000.0000000000
# mean      0.0000014041     0.0000004752     0.0000004665     0.0000005544
# std       0.0000012520     0.0000009953     0.0000006906     0.0000012147
# min       0.0000000000     0.0000000000     0.0000000000     0.0000000000
# 25%       0.0000010000     0.0000000000     0.0000000000     0.0000000000
# 50%       0.0000010000     0.0000000000     0.0000000000     0.0000000000
# 75%       0.0000010000     0.0000010000     0.0000010000     0.0000010000
# max       0.0000220000     0.0000190000     0.0000410000     0.0000570000
#
#                     16               32               64              128  \
# count 50000.0000000000 50000.0000000000 50000.0000000000 50000.0000000000
# mean      0.0000005090     0.0000005031     0.0000006107     0.0000007293
# std       0.0000005796     0.0000005536     0.0000005306     0.0000005251
# min       0.0000000000     0.0000000000     0.0000000000     0.0000000000
# 25%       0.0000000000     0.0000000000     0.0000000000     0.0000000000
# 50%       0.0000010000     0.0000000000     0.0000010000     0.0000010000
# 75%       0.0000010000     0.0000010000     0.0000010000     0.0000010000
# max       0.0000180000     0.0000170000     0.0000170000     0.0000180000
#
#                    256              512  ...          2097152  \
# count 50000.0000000000 50000.0000000000  ... 50000.0000000000
# mean      0.0000009789     0.0000015052  ...     0.0045425669
# std       0.0000003921     0.0000008046  ...     0.0003322347
# min       0.0000000000     0.0000010000  ...     0.0041350000
# 25%       0.0000010000     0.0000010000  ...     0.0044330000
# 50%       0.0000010000     0.0000010000  ...     0.0044720000
# 75%       0.0000010000     0.0000020000  ...     0.0045190000
# max       0.0000340000     0.0001000000  ...     0.0210370000
#
#                4194304          8388608         16777216         33554432  \
# count 50000.0000000000 50000.0000000000 50000.0000000000 50000.0000000000
# mean      0.0090661810     0.0181292382     0.0363013888     0.0727972486
# std       0.0005486493     0.0010060102     0.0019369421     0.0036911075
# min       0.0082420000     0.0164770000     0.0332370000     0.0666870000
# 25%       0.0088580000     0.0177260000     0.0355090000     0.0712550000
# 50%       0.0089290000     0.0178560000     0.0357470000     0.0716910000
# 75%       0.0090080000     0.0180040000     0.0360440000     0.0723130000
# max       0.0264410000     0.0370740000     0.0675020000     0.1328480000
#
#               67108864        134217728        268435456        536870912  \
# count 50000.0000000000 50000.0000000000 50000.0000000000 50000.0000000000
# mean      0.1459792105     0.2925265660     0.5862823975     1.1773335444
# std       0.0069651392     0.0130520494     0.0232851261     0.0403654021
# min       0.1339450000     0.2683890000     0.5422280000     1.0999800000
# 25%       0.1429730000     0.2865370000     0.5741327500     1.1510500000
# 50%       0.1438080000     0.2882905000     0.5777110000     1.1585200000
# 75%       0.1450040000     0.2906960000     0.5835680000     1.2013400000
# max       0.2122990000     0.3907530000     0.7619430000     1.4136000000
#
#             1073741824
# count 50000.0000000000
# mean      2.3725780540
# std       0.0618998048
# min       2.2030500000
# 25%       2.3197400000
# 50%       2.3644900000
# 75%       2.4141525000
# max       2.9594700000
#
# [8 rows x 31 columns]

# %%
cpu_reduction.mean().plot()

# %% [markdown]
# # GPU Reduction

# %%
gpu_reduction.describe()
# Out:
#                      1                2                4                8  \
# count 50000.0000000000 50000.0000000000 50000.0000000000 50000.0000000000
# mean      0.0000122265     0.0000071717     0.0000070232     0.0000071622
# std       0.0000226013     0.0000204529     0.0000021603     0.0000027057
# min       0.0000061440     0.0000051200     0.0000051200     0.0000051200
# 25%       0.0000081920     0.0000061440     0.0000061440     0.0000061440
# 50%       0.0000092160     0.0000071680     0.0000071680     0.0000061440
# 75%       0.0000133120     0.0000071680     0.0000071680     0.0000071680
# max       0.0048025600     0.0045598700     0.0000942080     0.0000409600
#
#                     16               32               64              128  \
# count 50000.0000000000 50000.0000000000 50000.0000000000 50000.0000000000
# mean      0.0000065421     0.0000066912     0.0000066723     0.0000066653
# std       0.0000010919     0.0000010942     0.0000009728     0.0000010652
# min       0.0000051200     0.0000061440     0.0000061440     0.0000061440
# 25%       0.0000061440     0.0000061440     0.0000061440     0.0000061440
# 50%       0.0000061440     0.0000061440     0.0000061440     0.0000061440
# 75%       0.0000071680     0.0000071680     0.0000071680     0.0000071680
# max       0.0000911360     0.0000440320     0.0000296960     0.0000890880
#
#                    256              512  ...          2097152  \
# count 50000.0000000000 50000.0000000000  ... 50000.0000000000
# mean      0.0000066826     0.0000067128  ...     0.0005043868
# std       0.0000011249     0.0000010566  ...     0.0000020785
# min       0.0000061440     0.0000061440  ...     0.0004986880
# 25%       0.0000061440     0.0000061440  ...     0.0005027840
# 50%       0.0000061440     0.0000061440  ...     0.0005038080
# 75%       0.0000071680     0.0000071680  ...     0.0005058560
# max       0.0000460800     0.0000430080  ...     0.0005580800
#
#                4194304          8388608         16777216         33554432  \
# count 50000.0000000000 50000.0000000000 50000.0000000000 50000.0000000000
# mean      0.0013593011     0.0027688047     0.0057922750     0.0122280613
# std       0.0000043808     0.0000247391     0.0000233411     0.0000425621
# min       0.0013424600     0.0027197400     0.0056954900     0.0120412000
# 25%       0.0013568000     0.0027607000     0.0057774100     0.0121989000
# 50%       0.0013588500     0.0027678700     0.0057917400     0.0122276000
# 75%       0.0013619200     0.0027760600     0.0058071000     0.0122563000
# max       0.0015042600     0.0075653100     0.0062986200     0.0132936000
#
#               67108864        134217728        268435456        536870912  \
# count 50000.0000000000 50000.0000000000 50000.0000000000 50000.0000000000
# mean      0.0257625273     0.0530825586     0.1077091220     0.2166417535
# std       0.0001167956     0.0001891126     0.0002505708     0.0007818575
# min       0.0253327000     0.0522609000     0.1064850000     0.2150330000
# 25%       0.0256788000     0.0529644000     0.1075570000     0.2164030000
# 50%       0.0257710000     0.0531057000     0.1077400000     0.2166320000
# 75%       0.0258499000     0.0532214000     0.1078900000     0.2168250000
# max       0.0278129000     0.0570900000     0.1154490000     0.2298990000
#
#             1073741824
# count 50000.0000000000
# mean      0.4349740997
# std       0.0008900223
# min       0.4325580000
# 25%       0.4346220000
# 50%       0.4349590000
# 75%       0.4352650000
# max       0.4545420000
#
# [8 rows x 31 columns]

# %%
gpu_reduction.mean().plot()

# %% [markdown]
# # Comparison

# %%
## Lines
plt.plot(cpu_reduction.mean(), label="CPU", color="blue")
plt.plot(gpu_reduction.mean(), label="GPU", color="green")

## Configuration
plt.title("Experiments")
plt.xlabel("Dataset size expressed as power of 2")
plt.ylabel("Seconds used to calculate");
plt.legend();

## Axis
plt.xscale("linear")

plt.yticks([0.000001, 0.00001, 0.0001, 0.001, 0.01, 0.1, 1.0, 2.0])
plt.yscale("log")

## Run the plot
plt.show()

# %%
comparison = pd.DataFrame({'cpu': cpu_reduction.mean(), 'gpu': gpu_reduction.mean()})

# %%
comparison
# Out:
#                     cpu          gpu
# 1          0.0000014041 0.0000122265
# 2          0.0000004752 0.0000071717
# 4          0.0000004665 0.0000070232
# 8          0.0000005544 0.0000071622
# 16         0.0000005090 0.0000065421
# 32         0.0000005031 0.0000066912
# 64         0.0000006107 0.0000066723
# 128        0.0000007293 0.0000066653
# 256        0.0000009789 0.0000066826
# 512        0.0000015052 0.0000067128
# 1024       0.0000029674 0.0000067577
# 2048       0.0000049448 0.0000069495
# 4096       0.0000094619 0.0000074599
# 8192       0.0000184260 0.0000084084
# 16384      0.0000362890 0.0000103301
# 32768      0.0000718008 0.0000141564
# 65536      0.0001417443 0.0000217758
# 131072     0.0002839911 0.0000378221
# 262144     0.0005715443 0.0000703452
# 524288     0.0011348340 0.0001332294
# 1048576    0.0022774922 0.0002570482
# 2097152    0.0045425669 0.0005043868
# 4194304    0.0090661810 0.0013593011
# 8388608    0.0181292382 0.0027688047
# 16777216   0.0363013888 0.0057922750
# 33554432   0.0727972486 0.0122280613
# 67108864   0.1459792105 0.0257625273
# 134217728  0.2925265660 0.0530825586
# 268435456  0.5862823975 0.1077091220
# 536870912  1.1773335444 0.2166417535
# 1073741824 2.3725780540 0.4349740997
